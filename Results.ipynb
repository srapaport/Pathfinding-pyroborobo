# %% [markdown]
# <h1>Résultats</h1>

# %% [markdown]
# <h2>Braitenberg VS Champion</h2>
# <p>Score moyen sur un échantillon de 10 parties</p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Braitenberg BLUE</th>
#         <td>328</td>
#         <td>294</td>
#         <td>234</td>
#         <td>291</td>
#         <td>106</td>
#     </tr>
#     <tr>
#         <th>Champion RED</th>
#         <td>228</td>
#         <td>155</td>
#         <td>9</td>
#         <td>253</td>
#         <td>130</td>
#     </tr>
# </table>
# </p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Braitenberg RED</th>
#         <td>337</td>
#         <td>311</td>
#         <td>259</td>
#         <td>308</td>
#         <td>125</td>
#     </tr>
#     <tr>
#         <th>Champion BLUE</th>
#         <td>208</td>
#         <td>154</td>
#         <td>40</td>
#         <td>244</td>
#         <td>140</td>
#     </tr>
# </table>
# </p>

# %% [markdown]
# <h2>Genetique VS Champion</h2>
# <p>Score moyen sur un échantillon de 10 parties</p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Genetique BLUE</th>
#         <td>280</td>
#         <td>302</td>
#         <td>173</td>
#         <td>301</td>
#         <td>162</td>
#     </tr>
#     <tr>
#         <th>Champion RED</th>
#         <td>265</td>
#         <td>217</td>
#         <td>153</td>
#         <td>277</td>
#         <td>115</td>
#     </tr>
# </table>
# </p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Genetique RED</th>
#         <td>232</td>
#         <td>253</td>
#         <td>190</td>
#         <td>298</td>
#         <td>124</td>
#     </tr>
#     <tr>
#         <th>Champion BLUE</th>
#         <td>284</td>
#         <td>283</td>
#         <td>141</td>
#         <td>279</td>
#         <td>89</td>
#     </tr>
# </table>
# </p>

# %% [markdown]
# <h2>Subsomption VS Champion</h2>
# <p>Score moyen sur un échantillon de 10 parties</p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Subsomption BLUE</th>
#         <td>357</td>
#         <td>262</td>
#         <td>251</td>
#         <td>312</td>
#         <td>151</td>
#     </tr>
#     <tr>
#         <th>Champion RED</th>
#         <td>201</td>
#         <td>182</td>
#         <td>13</td>
#         <td>256</td>
#         <td>110</td>
#     </tr>
# </table>
# </p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Subsomption RED</th>
#         <td>365</td>
#         <td>320</td>
#         <td>274</td>
#         <td>318</td>
#         <td>109</td>
#     </tr>
#     <tr>
#         <th>Champion BLUE</th>
#         <td>194</td>
#         <td>174</td>
#         <td>33</td>
#         <td>261</td>
#         <td>82</td>
#     </tr>
# </table>
# </p>
