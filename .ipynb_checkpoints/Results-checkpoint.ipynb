# %% [markdown]
# <h1>Résultats</h1>

# %% [markdown]
# <h2>Braitenberg VS Champion</h2>
# <p>Score moyen sur un échantillon de 10 parties</p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Braitenberg BLUE</th>
#         <td>328</td>
#         <td>294</td>
#         <td>234</td>
#         <td>291</td>
#         <td>106</td>
#     </tr>
#     <tr>
#         <th>Champion RED</th>
#         <td>228</td>
#         <td>155</td>
#         <td>9</td>
#         <td>253</td>
#         <td>130</td>
#     </tr>
# </table>
# </p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Braitenberg RED</th>
#         <td>337</td>
#         <td>311</td>
#         <td>259</td>
#         <td>308</td>
#         <td>125</td>
#     </tr>
#     <tr>
#         <th>Champion BLUE</th>
#         <td>208</td>
#         <td>154</td>
#         <td>40</td>
#         <td>244</td>
#         <td>140</td>
#     </tr>
# </table>
# </p>

# %% [markdown]
# <h2>Genetique VS Champion</h2>
# <p>Score moyen sur un échantillon de 10 parties</p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Genetique BLUE</th>
#         <td>328</td>
#         <td>294</td>
#         <td>234</td>
#         <td>291</td>
#         <td>106</td>
#     </tr>
#     <tr>
#         <th>Champion RED</th>
#         <td>228</td>
#         <td>155</td>
#         <td>9</td>
#         <td>253</td>
#         <td>130</td>
#     </tr>
# </table>
# </p>
# <p>
# <table>
#     <tr>
#         <th></th>
#         <th>Labyrinthe 0</th>
#         <th>Labyrinthe 1</th>
#         <th>Labyrinthe 2</th>
#         <th>Labyrinthe 3</th>
#         <th>Labyrinthe 4</th>
#     </tr>
#     <tr>
#         <th>Genetique RED</th>
#         <td>x</td>
#         <td>311</td>
#         <td>259</td>
#         <td>308</td>
#         <td>125</td>
#     </tr>
#     <tr>
#         <th>Champion BLUE</th>
#         <td>y</td>
#         <td>154</td>
#         <td>40</td>
#         <td>244</td>
#         <td>140</td>
#     </tr>
# </table>
# </p>
